# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
import io
import pandas as pd

# %%
file_name1 ='/content/gdrive/MyDrive/기계학습 기초/서울 트레인 데이터 셋/클러스터링 데이터셋-완료.xlsx'

# %%
df2 = pd.read_excel(file_name1)

# %%
df2
# Out:
#      Unnamed: 0   행정동  교과학원분야_소비인구      동네가게_소비인구      약국분야_소비인구  \
# 0             0  가락2동  1453.647328  659214.077308  128175.727819
# 1             1  가락본동    44.958165  341254.949849  175231.940299
# 2             2   가산동   929.135406  459869.574621  223007.483419
# 3             3  갈현1동   269.748989  449199.503513  121919.049886
# 4             4  갈현2동  7050.938845  785628.943668  130303.747620
# ..          ...   ...          ...            ...            ...
# 325         325  화곡본동   457.074675  826218.673447  117588.080011
# 326         326  화명1동    22.479082  443699.621353   40020.259694
# 327         327  화명3동  4428.379232   46943.817072  143266.685133
# 328         328  휘경1동    67.437247  426637.997812   76294.005653
# 329         329   흑석동    59.944220  453050.919627  191881.447328
#
#        외식 일식 소비 인구     중식/양식 소비인구    유흥분야_소비인구   자동차관련_소비인구  면적 대비 커피 소비 인구  \
# 0      7269.934552   55873.333479     0.000000  3274.453003   113129.104252
# ...

# %%
X = df2[['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구',
       '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구', '자동차관련_소비인구',
       '면적 대비 커피 소비 인구']]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(X)

# %%
factor_col = ['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구', '외식 일식 소비 인구',
       '중식/양식 소비인구', '유흥분야_소비인구', '자동차관련_소비인구', '면적 대비 커피 소비 인구']

# %%
df1 = pd.DataFrame(data_scale, columns=factor_col)

# %%
df1
# Out:
#      교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  유흥분야_소비인구  \
# 0       0.011765   0.017882   0.186194     0.015337    0.063593   0.000000
# 1       0.000185   0.009257   0.254550     0.048922    0.087081   0.010025
# 2       0.007453   0.012474   0.323951     0.270639    0.295147   0.000528
# 3       0.002033   0.012185   0.177105     0.054565    0.074305   0.077471
# 4       0.057780   0.021311   0.189285     0.036543    0.084227   0.005100
# ..           ...        ...        ...          ...         ...        ...
# 325     0.003573   0.022412   0.170814     0.009244    0.014372   0.000000
# 326     0.000000   0.012036   0.058135     0.000000    0.000061   0.000000
# 327     0.036220   0.001273   0.208116     0.036382    0.060618   0.025589
# 328     0.000370   0.011573   0.110828     0.000000    0.009272   0.000000
# 329     0.000308   0.012289   0.278736     0.022749    0.080888   0.000000
#
#      자동차관련_소비인구  면적 대비 커피 소비 인구
# 0      0.052752        0.073015
# ...

# %%
df1['행정동'] = df2['행정동']

# %%
df1
# Out:
#      교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  유흥분야_소비인구  \
# 0       0.011765   0.017882   0.186194     0.015337    0.063593   0.000000
# 1       0.000185   0.009257   0.254550     0.048922    0.087081   0.010025
# 2       0.007453   0.012474   0.323951     0.270639    0.295147   0.000528
# 3       0.002033   0.012185   0.177105     0.054565    0.074305   0.077471
# 4       0.057780   0.021311   0.189285     0.036543    0.084227   0.005100
# ..           ...        ...        ...          ...         ...        ...
# 325     0.003573   0.022412   0.170814     0.009244    0.014372   0.000000
# 326     0.000000   0.012036   0.058135     0.000000    0.000061   0.000000
# 327     0.036220   0.001273   0.208116     0.036382    0.060618   0.025589
# 328     0.000370   0.011573   0.110828     0.000000    0.009272   0.000000
# 329     0.000308   0.012289   0.278736     0.022749    0.080888   0.000000
#
#      자동차관련_소비인구  면적 대비 커피 소비 인구   행정동
# ...

# %%
df1['k-label'] = df2['k-label']

# %%
df1
# Out:
#      교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  유흥분야_소비인구  \
# 0       0.011765   0.017882   0.186194     0.015337    0.063593   0.000000
# 1       0.000185   0.009257   0.254550     0.048922    0.087081   0.010025
# 2       0.007453   0.012474   0.323951     0.270639    0.295147   0.000528
# 3       0.002033   0.012185   0.177105     0.054565    0.074305   0.077471
# 4       0.057780   0.021311   0.189285     0.036543    0.084227   0.005100
# ..           ...        ...        ...          ...         ...        ...
# 325     0.003573   0.022412   0.170814     0.009244    0.014372   0.000000
# 326     0.000000   0.012036   0.058135     0.000000    0.000061   0.000000
# 327     0.036220   0.001273   0.208116     0.036382    0.060618   0.025589
# 328     0.000370   0.011573   0.110828     0.000000    0.009272   0.000000
# 329     0.000308   0.012289   0.278736     0.022749    0.080888   0.000000
#
#      자동차관련_소비인구  면적 대비 커피 소비 인구   행정동  k-label
# ...

# %%
df1 = df1[['행정동', '교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구',
       '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구', '자동차관련_소비인구',
       '면적 대비 커피 소비 인구', 'k-label']]

# %%
df1
# Out:
#       행정동  교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  \
# 0    가락2동     0.011765   0.017882   0.186194     0.015337    0.063593
# 1    가락본동     0.000185   0.009257   0.254550     0.048922    0.087081
# 2     가산동     0.007453   0.012474   0.323951     0.270639    0.295147
# 3    갈현1동     0.002033   0.012185   0.177105     0.054565    0.074305
# 4    갈현2동     0.057780   0.021311   0.189285     0.036543    0.084227
# ..    ...          ...        ...        ...          ...         ...
# 325  화곡본동     0.003573   0.022412   0.170814     0.009244    0.014372
# 326  화명1동     0.000000   0.012036   0.058135     0.000000    0.000061
# 327  화명3동     0.036220   0.001273   0.208116     0.036382    0.060618
# 328  휘경1동     0.000370   0.011573   0.110828     0.000000    0.009272
# 329   흑석동     0.000308   0.012289   0.278736     0.022749    0.080888
#
#      유흥분야_소비인구  자동차관련_소비인구  면적 대비 커피 소비 인구  k-label
# 0     0.000000    0.052752        0.073015        0
# ...

# %%
data1 = df1[df1['k-label'] == 0]

# %%
data1
# Out:
#       행정동  교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  \
# 0    가락2동     0.011765   0.017882   0.186194     0.015337    0.063593
# 1    가락본동     0.000185   0.009257   0.254550     0.048922    0.087081
# 3    갈현1동     0.002033   0.012185   0.177105     0.054565    0.074305
# 4    갈현2동     0.057780   0.021311   0.189285     0.036543    0.084227
# 14   고척1동     0.006222   0.011164   0.130812     0.003794    0.063333
# ..    ...          ...        ...        ...          ...         ...
# 315   행운동     0.002402   0.017708   0.221558     0.023199    0.009506
# 320  화곡1동     0.000370   0.025695   0.299264     0.043038    0.118739
# 324  화곡8동     0.002094   0.016043   0.194009     0.034807    0.013903
# 327  화명3동     0.036220   0.001273   0.208116     0.036382    0.060618
# 329   흑석동     0.000308   0.012289   0.278736     0.022749    0.080888
#
#      유흥분야_소비인구  자동차관련_소비인구  면적 대비 커피 소비 인구  k-label
# 0     0.000000    0.052752        0.073015        0
# ...

# %%
print(data1['교과학원분야_소비인구'].mean())
print(data1['동네가게_소비인구'].mean())
print(data1['약국분야_소비인구'].mean())
print(data1['외식 일식 소비 인구'].mean())
print(data1['중식/양식 소비인구'].mean())
print(data1['유흥분야_소비인구'].mean())
print(data1['자동차관련_소비인구'].mean())
print(data1['면적 대비 커피 소비 인구'].mean())
# Out:
# 0.013157814488820991
# 0.023281895564998573
# 0.21134182383816666
# 0.04750265865893244
# 0.06329256977043327
# 0.008137931275088273
# 0.06702291426955101
# 0.13318221567492322

# %%
data2 = df1[df1['k-label'] == 1]

# %%
data2
# Out:
#       행정동  교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  \
# 5     강일동     0.007761   0.010203   0.065145     0.001061    0.000000
# 6    개금1동     0.001170   0.006558   0.146573     0.000048    0.002160
# 7    개금3동     0.000924   0.007254   0.009100     0.000000    0.004094
# 8    개봉2동     0.004743   0.010208   0.146987     0.001559    0.015768
# 9    개봉3동     0.000000   0.010070   0.073396     0.000627    0.020625
# ..    ...          ...        ...        ...          ...         ...
# 322  화곡3동     0.013921   0.008783   0.092945     0.043761    0.010391
# 323  화곡4동     0.000000   0.015224   0.100694     0.005064    0.008248
# 325  화곡본동     0.003573   0.022412   0.170814     0.009244    0.014372
# 326  화명1동     0.000000   0.012036   0.058135     0.000000    0.000061
# 328  휘경1동     0.000370   0.011573   0.110828     0.000000    0.009272
#
#      유흥분야_소비인구  자동차관련_소비인구  면적 대비 커피 소비 인구  k-label
# 5     0.000000    0.020521        0.017002        1
# ...

# %%
data3 = df1[df1['k-label'] == 2]

# %%
data3
# Out:
#              행정동  교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  \
# 117         부전2동     0.014476   0.005615   0.339320     0.224418    0.191821
# 149          서교동     0.001910   0.025200   0.507358     0.941014    0.784258
# 191          신사동     0.014845   0.019010   0.454502     0.413723    0.359946
# 220         역삼1동     0.333929   0.022354   1.000000     1.000000    1.000000
# 280  종로1.2.3.4가동     0.005975   0.008311   0.669965     0.635617    0.663888
#
#      유흥분야_소비인구  자동차관련_소비인구  면적 대비 커피 소비 인구  k-label
# 117   1.000000    0.000000        0.952453        2
# 149   0.113876    0.009054        0.794507        2
# 191   0.102972    0.044544        1.000000        2
# 220   0.178948    0.213061        0.809415        2
# 280   0.320172    0.022211        0.504383        2

# %%
data4 = df1[df1['k-label'] == 3]

# %%
data4
# Out:
#         행정동  교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  \
# 2       가산동     0.007453   0.012474   0.323951     0.270639    0.295147
# 22     구로3동     0.000000   0.007119   0.276885     0.247665    0.283638
# 71      동선동     0.028459   0.009164   0.215115     0.119516    0.196747
# 98     반포4동     0.101269   0.015629   0.354493     0.114066    0.132556
# 106    방이2동     0.075952   0.013491   0.159798     0.095047    0.104931
# 130     사직동     0.002464   0.024243   0.123770     0.231588    0.210417
# 133    삼성2동     0.103055   0.012501   0.142894     0.186573    0.104913
# 139    상계2동     0.004620   0.015554   0.198657     0.170319    0.197719
# 152     서원동     0.000185   0.012725   0.173470     0.085304    0.084210
# 154    서초2동     0.161636   0.008205   0.209520     0.099661    0.118271
# 155    서초3동     0.049341   0.009631   0.330405     0.188373    0.229039
# 156    서초4동     0.009979   0.011145   0.398838     0.217794    0.209870
# ...

# %%
data5 = df1[df1['k-label'] == 4]

# %%
data5
# Out:
#      행정동  교과학원분야_소비인구  동네가게_소비인구  약국분야_소비인구  외식 일식 소비 인구  중식/양식 소비인구  \
# 58  대치1동     1.000000   0.009732   0.214864     0.007508    0.008830
# 59  대치2동     0.593199   0.014181   0.188088     0.096703    0.200477
# 60  대치4동     0.819638   0.009530   0.209019     0.284256    0.251702
# 83   목1동     0.403597   0.020906   0.380595     0.163647    0.133111
# 87   목5동     0.573981   0.016717   0.188697     0.019807    0.049239
#
#     유흥분야_소비인구  자동차관련_소비인구  면적 대비 커피 소비 인구  k-label
# 58   0.000000    0.000000        0.178073        4
# 59   0.000352    0.045872        0.204475        4
# 60   0.007211    0.074481        0.721228        4
# 83   0.000000    0.000000        0.295698        4
# 87   0.000000    0.000000        0.084252        4

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %%
sns.pairplot(data5)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.pairplot(data4)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.pairplot(data2)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.pairplot(data1)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
print(data1['교과학원분야_소비인구'].mean())
print(data1['동네가게_소비인구'].mean())
print(data1['약국분야_소비인구'].mean())
print(data1['외식 일식 소비 인구'].mean())
print(data1['중식/양식 소비인구'].mean())
print(data1['유흥분야_소비인구'].mean())
print(data1['자동차관련_소비인구'].mean())
print(data1['면적 대비 커피 소비 인구'].mean())
# Out:
# 0.013157814488820991
# 0.023281895564998573
# 0.21134182383816666
# 0.04750265865893244
# 0.06329256977043327
# 0.008137931275088273
# 0.06702291426955101
# 0.13318221567492322

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(8)
consumer_population = ['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구', '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구','자동차관련_소비인구','면적 대비 커피 소비 인구']
values = [data1['교과학원분야_소비인구'].mean(),data1['동네가게_소비인구'].mean(),data1['약국분야_소비인구'].mean(),data1['외식 일식 소비 인구'].mean(), data1['중식/양식 소비인구'].mean(),data1['유흥분야_소비인구'].mean(),data1['자동차관련_소비인구'].mean(), data1['면적 대비 커피 소비 인구'].mean()]

plt.barh(y, values)
plt.yticks(y, consumer_population)

plt.show()

# %%
print(data2['교과학원분야_소비인구'].mean())
print(data2['동네가게_소비인구'].mean())
print(data2['약국분야_소비인구'].mean())
print(data2['외식 일식 소비 인구'].mean())
print(data2['중식/양식 소비인구'].mean())
print(data2['유흥분야_소비인구'].mean())
print(data2['자동차관련_소비인구'].mean())
print(data2['면적 대비 커피 소비 인구'].mean())
# Out:
# 0.009664039076693548
# 0.007997521278981297
# 0.07441040970998686
# 0.009004653391217698
# 0.016779933969669127
# 0.0015354502196306414
# 0.014123611782882345
# 0.05415481818372141

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(8)
consumer_population = ['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구', '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구','자동차관련_소비인구','면적 대비 커피 소비 인구']
values = [data2['교과학원분야_소비인구'].mean(),data2['동네가게_소비인구'].mean(),data2['약국분야_소비인구'].mean(),data2['외식 일식 소비 인구'].mean(), data2['중식/양식 소비인구'].mean(),data2['유흥분야_소비인구'].mean(),data2['자동차관련_소비인구'].mean(), data2['면적 대비 커피 소비 인구'].mean()]

plt.barh(y, values)
plt.yticks(y, consumer_population)

plt.show()

# %%
print(data3['교과학원분야_소비인구'].mean())
print(data3['동네가게_소비인구'].mean())
print(data3['약국분야_소비인구'].mean())
print(data3['외식 일식 소비 인구'].mean())
print(data3['중식/양식 소비인구'].mean())
print(data3['유흥분야_소비인구'].mean())
print(data3['자동차관련_소비인구'].mean())
print(data3['면적 대비 커피 소비 인구'].mean())
# Out:
# 0.0742269311336749
# 0.01609790303595976
# 0.5942289272042856
# 0.6429542933375518
# 0.5999826531967921
# 0.34319380935967536
# 0.05777402221373297
# 0.8121516252165112

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(8)
consumer_population = ['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구', '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구','자동차관련_소비인구','면적 대비 커피 소비 인구']
values = [data3['교과학원분야_소비인구'].mean(),data3['동네가게_소비인구'].mean(),data3['약국분야_소비인구'].mean(),data3['외식 일식 소비 인구'].mean(), data3['중식/양식 소비인구'].mean(),data3['유흥분야_소비인구'].mean(),data3['자동차관련_소비인구'].mean(), data3['면적 대비 커피 소비 인구'].mean()]

plt.barh(y, values)
plt.yticks(y, consumer_population)

plt.show()

# %%
print(data4['교과학원분야_소비인구'].mean())
print(data4['동네가게_소비인구'].mean())
print(data4['약국분야_소비인구'].mean())
print(data4['외식 일식 소비 인구'].mean())
print(data4['중식/양식 소비인구'].mean())
print(data4['유흥분야_소비인구'].mean())
print(data4['자동차관련_소비인구'].mean())
print(data4['면적 대비 커피 소비 인구'].mean())
# Out:
# 0.04319282417909699
# 0.012550545570890276
# 0.25830042802109865
# 0.2092805829245545
# 0.19811153329316092
# 0.04428555967580724
# 0.08880418230021976
# 0.35515222110166395

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(8)
consumer_population = ['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구', '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구','자동차관련_소비인구','면적 대비 커피 소비 인구']
values = [data4['교과학원분야_소비인구'].mean(),data4['동네가게_소비인구'].mean(),data4['약국분야_소비인구'].mean(),data4['외식 일식 소비 인구'].mean(), data4['중식/양식 소비인구'].mean(),data4['유흥분야_소비인구'].mean(),data4['자동차관련_소비인구'].mean(), data4['면적 대비 커피 소비 인구'].mean()]

plt.barh(y, values)
plt.yticks(y, consumer_population)

plt.show()

# %%
print(data5['교과학원분야_소비인구'].mean())
print(data5['동네가게_소비인구'].mean())
print(data5['약국분야_소비인구'].mean())
print(data5['외식 일식 소비 인구'].mean())
print(data5['중식/양식 소비인구'].mean())
print(data5['유흥분야_소비인구'].mean())
print(data5['자동차관련_소비인구'].mean())
print(data5['면적 대비 커피 소비 인구'].mean())
# Out:
# 0.6780830356049825
# 0.014213216747266815
# 0.2362526123307473
# 0.11438401311823114
# 0.12867166833037577
# 0.0015124868097734037
# 0.024070497345382417
# 0.296745397177995

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(8)
consumer_population = ['교과학원분야_소비인구', '동네가게_소비인구', '약국분야_소비인구', '외식 일식 소비 인구', '중식/양식 소비인구', '유흥분야_소비인구','자동차관련_소비인구','면적 대비 커피 소비 인구']
values = [data5['교과학원분야_소비인구'].mean(),data5['동네가게_소비인구'].mean(),data5['약국분야_소비인구'].mean(),data5['외식 일식 소비 인구'].mean(), data5['중식/양식 소비인구'].mean(),data5['유흥분야_소비인구'].mean(),data5['자동차관련_소비인구'].mean(), data5['면적 대비 커피 소비 인구'].mean()]

plt.barh(y, values)
plt.yticks(y, consumer_population)

plt.show()
